# %% [markdown]
# # 03 Model Evaluation

# %% [markdown]
# - Done By: Kedar Raju Pawar
# - date:2026-02-25 time: 16:00:00

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot
from utils_preprocessing import preprocess

# %% [markdown]
# ## Load Model

# %%
df = pd.read_csv("../../02_Data_Management/04_Processed_Data/analytics_dataset.csv")
df = preprocess(df)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 42 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   laptop_type                1000 non-null   object
#  1   screen_size_inch           1000 non-null   float64
#  2   display_resolution_width   1000 non-null   int64
#  3   display_resolution_height  1000 non-null   int64
#  4   panel_type                 1000 non-null   object
#  5   is_touchscreen             1000 non-null   int64
#  6   resolution_class           1000 non-null   object
#  7   cpu_brand                  1000 non-null   object
#  8   cpu_family                 1000 non-null   object
#  9   cpu_generation             821 non-null    float64
#  10  clock_speed_ghz            1000 non-null   float64
#  11  cpu_tier                   1000 non-null   int64
#  12  gpu_brand                  1000 non-null   object
# ...

# %% [markdown]
# ### Predict

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# ### Metrics

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import numpy as np

r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print("R²:", r2)
print("MAE:", mae)
print("RMSE:", rmse)
# Out:
# R²: 0.5363200986115992
# MAE: 14659.284726541864
# RMSE: 22080.761737060566

# %% [markdown]
# ### conclusion
# -The Linear Regression model explains approximately 53% of the variance in laptop prices using hardware specifications and brand features (R² ≈ 0.53).
#
# - On average, predictions deviate by approximately ₹7,200 from the actual market price (MAE), with larger deviations reflected in the RMSE value.
#
# - While the model captures core structural pricing drivers, additional improvements such as regularization, interaction terms, or non-linear models may further enhance predictive performance.
#
# - Overall, the baseline model provides a reasonable and interpretable foundation for laptop price prediction.
