# %% [markdown]
# # 2 Feature Importance Analysis

# %% [markdown]
# - Done By: Kedar Raju Pawar
# - date:2026-02-25 time: 15:30:00

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot
from utils_preprocessing import preprocess

# %% [markdown]
# ## load Model

# %%
import pandas as pd

import joblib
df = pd.read_csv("../../02_Data_Management/04_Processed_Data/analytics_dataset.csv")
model = joblib.load("linear_model.pkl")

df = preprocess(df)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 42 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   laptop_type                1000 non-null   object
#  1   screen_size_inch           1000 non-null   float64
#  2   display_resolution_width   1000 non-null   int64
#  3   display_resolution_height  1000 non-null   int64
#  4   panel_type                 1000 non-null   object
#  5   is_touchscreen             1000 non-null   int64
#  6   resolution_class           1000 non-null   object
#  7   cpu_brand                  1000 non-null   object
#  8   cpu_family                 1000 non-null   object
#  9   cpu_generation             821 non-null    float64
#  10  clock_speed_ghz            1000 non-null   float64
#  11  cpu_tier                   1000 non-null   int64
#  12  gpu_brand                  1000 non-null   object
# ...

# %%
# Load trained model

# Get feature names directly from model
feature_names = model.feature_names_in_

print("Model feature count:", len(feature_names))
print("Coefficient count:", len(model.coef_))

coefficients = pd.DataFrame({
    "Feature": feature_names,
    "Coefficient": model.coef_
}).sort_values(by="Coefficient", ascending=False)

coefficients
# Out:
# Model feature count: 32
# Coefficient count: 32
#                       Feature   Coefficient
# 27              Company_RAZER  89490.980866
# 23                 Company_LG  35617.912722
# 25          Company_MICROSOFT  25005.218398
# 26                Company_MSI  21255.589308
# 14              Company_APPLE  20177.379579
# 28            Company_SAMSUNG  18121.219386
# 19             Company_GOOGLE  15199.012683
# 21             Company_HUAWEI  14430.029589
# 13                  weight_kg  14151.684224
# 29            Company_TOSHIBA  13574.038261
# 20                 Company_HP  11013.251445
# 17               Company_DELL   8303.883074
# 15               Company_ASUS   8236.914213
# 22             Company_LENOVO   7806.637440
# 6                    cpu_tier   5910.431862
# 24           Company_MEDIACOM   4910.831437
# 3              is_touchscreen   3773.565443
# 30               Company_VERO   3076.009196
# 7                      ram_gb   2844.234472
# ...

# %% [markdown]
# ## CONCLUSION

# %% [markdown]
# - The Linear Regression model was built to quantify the key factors influencing laptop prices using hardware specifications and brand indicators.
#
# - After proper preprocessing (encoding, imputation, and numeric feature selection), the model was trained on 32 features with full alignment between feature count and coefficients, ensuring a stable and reproducible pipeline.
#
# - Key Insights:
#
# - Brand premium plays a significant role in pricing, even after controlling for hardware.
#
# - CPU tier, RAM, clock speed, and SSD capacity are strong positive price drivers.
#
# - Performance-related specifications contribute more significantly to pricing than traditional storage (HDD).
#
# - Pricing behavior can be effectively explained using structured hardware and brand features.
#
# - Overall, the model provides a clear, interpretable baseline for understanding laptop pricing dynamics and establishes a strong foundation for further advanced modeling techniques.
