# %%
🐍 Python — Statistical + Relationship + Modeling Questions
(No overlap with SQL — this is pattern & prediction layer)

# which numeric features correlate most strongly with price
# build correlation matrix and identify top 5 price drivers
# does price follow normal or skewed distribution
# compare price distributions across cpu tiers using boxplots
# test whether high-ram group mean price is statistically higher (t-test)
# build simple linear regression to estimate price from specs
# check feature importance using tree-based model
# create a composite performance score and test its correlation with price
# detect natural laptop clusters using k-means
# profile each cluster by specs and price level
# build a “value index” = predicted price vs actual price gap
# find top undervalued and overvalued models
Signal shown: stats thinking, ML basics, hypothesis testing. Recruiters perk up here. 📈
is this enough?
